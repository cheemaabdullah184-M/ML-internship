# %% [markdown]
# <a href="https://colab.research.google.com/github/cheemaabdullah184-M/ML-internship/blob/main/work_notebooks_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME:Abdullah Ahmad Cheema

# %% [markdown]
# I chose the Freelancer Proposal Success Prediction lane because freelancers often spend significant time applying to projects without knowing which opportunities are most likely to result in a hire. Machine learning can identify patterns in historical proposal data and help estimate the likelihood of success, allowing freelancers to focus on better opportunities.

# %% [markdown]
# Can we predict whether a freelancer's proposal will be accepted?
# Unit of Analysis
#
# One proposal submitted by one freelancer.
#
# Output
#
# A probability that the proposal will be accepted.
#
# Action
#
# A freelancer decides whether to apply for a project.
#
# Cost of Wrong Recommendation
#
# If the model predicts success incorrectly, freelancers may waste time applying for projects that are unlikely to hire them.

# %%
import pandas as pd

df = pd.read_csv("/content/sample_data/california_housing_train.csv")

df.head()
print("Rows, Columns:", df.shape)

print("\nColumns:")
print(df.columns)

print("\nMissing Values:")
print(df.isnull().sum())

print("\nSummary:")
print(df.describe())
